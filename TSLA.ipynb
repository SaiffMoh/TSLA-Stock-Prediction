# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

import keras
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
data_dir = 'TSLA.csv'
df = pd.read_csv(data_dir, parse_dates= True , index_col= "Date")

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2956 entries, 2010-06-29 to 2022-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2956 non-null   float64
#  1   High       2956 non-null   float64
#  2   Low        2956 non-null   float64
#  3   Close      2956 non-null   float64
#  4   Adj Close  2956 non-null   float64
#  5   Volume     2956 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 161.7 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2956.000000  2956.000000  2956.000000  2956.000000  2956.000000
# mean    138.691296   141.771603   135.425953   138.762183   138.762183
# std     250.044839   255.863239   243.774157   250.123115   250.123115
# min       3.228000     3.326000     2.996000     3.160000     3.160000
# 25%      19.627000    20.402000    19.127500    19.615000    19.615000
# 50%      46.656999    47.487001    45.820002    46.545000    46.545000
# 75%      68.057001    69.357500    66.911501    68.103998    68.103998
# max    1234.410034  1243.489990  1217.000000  1229.910034  1229.910034
#
#              Volume
# count  2.956000e+03
# mean   3.131449e+07
# std    2.798383e+07
# min    5.925000e+05
# 25%    1.310288e+07
# 50%    2.488680e+07
# 75%    3.973875e+07
# max    3.046940e+08

# %%
plt.figure(figsize=(15, 6))
df['Open'].plot()
df['Close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price of Tesla")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel(None)
plt.title("Sales Volume of Tesla")
plt.tight_layout()
plt.show()

# %%
# We'll use pct_change to find the percent change for each day
plt.figure(figsize=(15, 6))
df['Adj Close'].pct_change().hist(bins=50)
plt.ylabel('Daily Return')
plt.title(f'Tesla Dialy Return')
plt.tight_layout()
plt.show()

# %%
dataset = df["Close"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (2956, 1)

# %%
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %%
train_size = int(len(data)*.75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 2217 Test Size : 739

# %%
train_data.shape, test_data.shape
# Out:
# ((2217, 1), (799, 1))

# %%
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape , y_train.shape
# Out:
# ((2157, 60, 1), (2157,))

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= ["mean_absolute_error"])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_16 (LSTM)                       │ (None, 60, 50)              │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_17 (LSTM)                       │ (None, 64)                  │          29,440 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 42,465 (165.88 KB)
#  Trainable params: 42,465 (165.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.6624e-04 - mean_absolute_error: 0.0084
# Epoch 2/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.0039e-06 - mean_absolute_error: 0.0016
# Epoch 3/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5441e-06 - mean_absolute_error: 0.0017
# Epoch 4/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5963e-06 - mean_absolute_error: 0.0016
# Epoch 5/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6349e-06 - mean_absolute_error: 0.0015
# Epoch 6/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.3068e-06 - mean_absolute_error: 0.0017
# Epoch 7/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3178e-06 - mean_absolute_error: 0.0017
# Epoch 8/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3208e-06 - mean_absolute_error: 0.0017
# Epoch 9/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.8112e-06 - mean_absolute_error: 0.0017
# Epoch 10/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8046e-06 - mean_absolute_error: 0.0016
# Epoch 11/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5088e-06 - mean_absolute_error: 0.0018
# Epoch 12/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3371e-06 - mean_absolute_error: 0.0015
# Epoch 13/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2077e-06 - mean_absolute_error: 0.0020
# Epoch 14/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.3272e-06 - mean_absolute_error: 0.0013
# Epoch 15/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0055e-06 - mean_absolute_error: 0.0015
# Epoch 16/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5462e-06 - mean_absolute_error: 0.0014
# Epoch 17/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5481e-06 - mean_absolute_error: 0.0014
# Epoch 18/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.8434e-06 - mean_absolute_error: 0.0015
# Epoch 19/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7541e-06 - mean_absolute_error: 0.0022
# Epoch 20/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8168e-06 - mean_absolute_error: 0.0012
# Epoch 21/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8196e-06 - mean_absolute_error: 0.0012
# Epoch 22/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9833e-06 - mean_absolute_error: 0.0016
# Epoch 23/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5345e-06 - mean_absolute_error: 0.0017
# Epoch 24/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2872e-06 - mean_absolute_error: 0.0016
# Epoch 25/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2495e-06 - mean_absolute_error: 0.0013
# Epoch 26/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0723e-06 - mean_absolute_error: 0.0013
# Epoch 27/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.1888e-06 - mean_absolute_error: 0.0013
# Epoch 28/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9154e-06 - mean_absolute_error: 0.0013
# Epoch 29/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5380e-06 - mean_absolute_error: 0.0015
# Epoch 30/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1793e-06 - mean_absolute_error: 0.0011
# Epoch 31/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2094e-06 - mean_absolute_error: 0.0013
# Epoch 32/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9521e-06 - mean_absolute_error: 9.7691e-04
# Epoch 33/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3210e-06 - mean_absolute_error: 0.0011
# Epoch 34/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1150e-06 - mean_absolute_error: 0.0011
# Epoch 35/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2
100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6015e-06 - mean_absolute_error: 9.4340e-04
# Epoch 82/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5481e-06 - mean_absolute_error: 9.0952e-04
# Epoch 83/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8208e-06 - mean_absolute_error: 9.7469e-04
# Epoch 84/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4907e-06 - mean_absolute_error: 9.0017e-04
# Epoch 85/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4638e-06 - mean_absolute_error: 9.1135e-04
# Epoch 86/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4057e-06 - mean_absolute_error: 8.5925e-04
# Epoch 87/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5043e-06 - mean_absolute_error: 8.8513e-04
# Epoch 88/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4525e-06 - mean_absolute_error: 8.4284e-04
# Epoch 89/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.8271e-06 - mean_absolute_error: 9.9822e-04
# Epoch 90/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.9200e-06 - mean_absolute_error: 0.0011
# Epoch 91/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0255e-06 - mean_absolute_error: 0.0011
# Epoch 92/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.9358e-06 - mean_absolute_error: 0.0010

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((739, 60, 1), (739,))

# %%
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# (739, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 22.38

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Tesla Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['Close'], linewidth= 3)
plt.plot(test['Close'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 30
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0, 0])
    print(forcast)
    Xin = insert_end(Xin, out[0, 0])
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [0.7645643]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [0.7645643, 0.733224]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [0.7645643, 0.733224, 0.69647425]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [0.7645643, 0.733224, 0.69647425, 0.6595714]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [0.7645643, 0.733224, 0.69647425, 0.6595714, 0.6245354]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [0.7645643, 0.733224, 0.69647425, 0.6595714, 0.6245354, 0.5924627]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [0.7645643, 0.733224, 0.69647425, 0.6595714, 0.6245354, 0.5924627, 0.56384474]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [0.7645643, 0.733224, 0.69647425, 0.6595714, 0.6245354, 0.5924627, 0.56384474, 0.5387469, 0.51695496, 0.49809155, 0.48170567, 0.46733627, 0.45455444, 0.4429875, 0.43232962, 0.4223429, 0.41285205, 0.4037354, 0.3949145, 0.38634366, 0.37800044, 0.36987758, 0.36197644, 0.35430253, 0.3468619, 0.33965927, 0.33269677, 0.32597375, 0.31948665, 0.31322956]

# %%
time
# Out:
# [Timestamp('2022-03-24 00:00:00'),
#  Timestamp('2022-03-25 00:00:00'),
#  Timestamp('2022-03-26 00:00:00'),
#  Timestamp('2022-03-27 00:00:00'),
#  Timestamp('2022-03-28 00:00:00'),
#  Timestamp('2022-03-29 00:00:00'),
#  Timestamp('2022-03-30 00:00:00'),
#  Timestamp('2022-03-31 00:00:00'),
#  Timestamp('2022-04-01 00:00:00'),
#  Timestamp('2022-04-02 00:00:00'),
#  Timestamp('2022-04-03 00:00:00'),
#  Timestamp('2022-04-04 00:00:00'),
#  Timestamp('2022-04-05 00:00:00'),
#  Timestamp('2022-04-06 00:00:00'),
#  Timestamp('2022-04-07 00:00:00'),
#  Timestamp('2022-04-08 00:00:00'),
#  Timestamp('2022-04-09 00:00:00'),
#  Timestamp('2022-04-10 00:00:00'),
#  Timestamp('2022-04-11 00:00:00'),
#  Timestamp('2022-04-12 00:00:00'),
#  Timestamp('2022-04-13 00:00:00'),
#  Timestamp('2022-04-14 00:00:00'),
#  Timestamp('2022-04-15 00:00:00'),
#  Timestamp('2022-04-16 00:00:00'),
#  Timestamp('2022-04-17 00:00:00'),
#  Timestamp('2022-04-18 00:00:00'),
#  Timestamp('2022-04-19 00:00:00'),
#  Timestamp('2022-04-20 00:00:00'),
#  Timestamp('2022-04-21 00:00:00'),
#  Timestamp('2022-04-22 00:00:00')]

# %%
forcasted_output = np.asanyarray(forcast)
forcasted_output = forcasted_output.reshape(-1, 1)
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"

# %%
df_result
# Out:
#          Date  Forecasted
# 0  2022-03-24  941.089294
# 1  2022-03-25  902.642578
# 2  2022-03-26  857.559814
# 3  2022-03-27  812.289246
# 4  2022-03-28  769.308838
# 5  2022-03-29  729.963684
# 6  2022-03-30  694.856567
# 7  2022-03-31  664.067810
# 8  2022-04-01  637.334534
# 9  2022-04-02  614.193787
# 10 2022-04-03  594.092407
# 11 2022-04-04  576.464783
# 12 2022-04-05  560.784668
# 13 2022-04-06  546.594910
# 14 2022-04-07  533.520386
# 15 2022-04-08  521.269165
# 16 2022-04-09  509.626251
# 17 2022-04-10  498.442413
# 18 2022-04-11  487.621368
# 19 2022-04-12  477.107086
# 20 2022-04-13  466.872040
# 21 2022-04-14  456.907318
# 22 2022-04-15  447.214600
# 23 2022-04-16  437.800629
# 24 2022-04-17  428.672852
# 25 2022-04-18  419.837006
# 26 2022-04-19  411.295746
# 27 2022-04-20  403.048309
# 28 2022-04-21  395.090240
# 29 2022-04-22  387.414368

# %%
plt.figure(figsize=(16, 8))
plt.title('Tesla Close Stock Price Forecasting For Next 30 Days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close' ,fontsize=18)
plt.plot(df['Close'])
plt.plot(df_result.set_index('Date')[['Forecasted']])
